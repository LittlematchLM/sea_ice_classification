# %%
from PIL import Image
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
mask_dir = r'E:\python_workfile\sea_ice_classification\data\mask\osisaf\pic'

# %%
mask_paths = glob.glob(mask_dir + '\\*.png')

# %%
img = Image.open(mask_paths[0])
img_arr = np.array(img)

# %%
plt.imshow(img_arr[:,:,:3])

# %%
import pandas as pd

# %%
plt.hist(img_arr[:,:,0],bins=2)
# Out:
# (array([[   0., 1620.],
#         [   0., 1620.],
#         [   0., 1620.],
#         ...,
#         [   0., 1620.],
#         [   0., 1620.],
#         [   0., 1620.]]),
#  array([  0. , 127.5, 255. ]),
#  <a list of 1620 BarContainer objects>)

# %%
import numpy as np
from collections import  Counter
data = np.ravel(img_arr[:,:,0])
Counter(data)
# Out:
# Counter({255: 542100, 0: 2011581, 125: 61854, 128: 8865})
