# %%
from PIL import Image
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import cv2
import glob

# %%
files = glob.glob(r'E:\python_workfile\sea_ice_classification\training7\dataset\aari\npy_real\*.npy')

# %%
a = np.load(files[0])

# %%
plt.imshow(a,cmap=plt.cm.jet)
plt.colorbar()

# %%
a.max()
# Out:
# 4

# %%
a.min()
# Out:
# 0

# %%
plt.imshow(display_list[i],vmin=0,vmax=5,cmap = plt.cm.jet)
